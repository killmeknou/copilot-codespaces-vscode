# %% [markdown]
# <a href="https://colab.research.google.com/github/killmeknou/copilot-codespaces-vscode/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_4%EA%B0%95_%EC%8B%A4%EC%8A%B5(%ED%95%99%EC%8A%B5%EC%9E%90%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #4강 순차 구조

# %% [markdown]
# ##4.2 순차 구조의 이해

# %% [markdown]
# **사용자 입력**

# %%
# 사용자 입력
rad = input()

# 출력
print(rad)
# Out:
# 40
# 40

# %% [markdown]
# **기호 삼각 모형으로 출력하기**
#
# ---
#
# <img width=200 src="data:image/png;base64,...">

# %%
#기호 사용자 입력
symbol = input()


#삼각 모형 출력
for i in range(4):
    print(" " * 4 - i, symbol * i, " " * 4 - i)

# %% [markdown]
# **초를 분과 초로 변환하기**
#
# ---
# 시간을 입력하세요(초단위): 200 ↵
#
# 입력하신 시간은 3분 20초 입니다.

# %%
#초 사용자 입력

#분 계산

#남은 초 계산

#출력

# %% [markdown]
# **사용자로부터 반지름을 입력받고 넓이와 둘레를 출력?**

# %%
# 원의 넓이와 둘레 계산 프로그램
#반지름 할당
rad = 40
#넓이 출력
print(f"원의 넓이는 {rad ** 2 * 3.141:.2f} 입니다.")
#둘레 출력
print(f"원의 둘레는 {2 * rad * 3.141:.2f } 입니다.")

# %% [markdown]
# **복리 예금 계산기**
#
# ---
#
# <img width=350 src="data:image/png;base64,...">
#
# ---
#
# 원금을 입력하세요(만원): 100 ↵
#
# 이율을 입력하세요(%): 5 ↵
#
# 기간을 입력하세요(년): 10 ↵
#
# 10년 후 받을 금액은 약 162.89만원입니다.

# %%
##원금, 이율, 기간 사용자 입력


##금액 계산

##출력
